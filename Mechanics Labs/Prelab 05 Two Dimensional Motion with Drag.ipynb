# %% [markdown]
# # Prelab 05: Two Dimensional Motion with Drag

# %% [markdown]
# _Name:_

# %%
import numpy as np

# %% [markdown]
# ## Drag force on a spherical object in projectile motion

# %% [markdown]
# <strong><font color=blue>Problem 5.1: Look up, and write below, a reasonable value for the density of air at room temperature, expressed in units of $\text{kg}/\text{m}^3$.

# %% [markdown]
# _Write your answer here:_

# %% [markdown]
# <strong><font color=blue>Problem 5.2: Consider a cylinder with height $h$ and radius $r$. What is its cross sectional area when it is moving parallel to its axis (below, left)? What about when it is moving perpendicular to its axis (below, right)? If you aren't sure why these values are different, make sure to discuss this concept with your group or GSI during the lab.

# %% [markdown]
# ![cross-sectional-area.png](attachment:cross-sectional-area.png)

# %% [markdown]
# _Write your answer here:_

# %% [markdown]
# <strong><font color=blue>Problem 5.3: Below is plotted the (near-parabolic) trajectory of a ball thrown near the Earth's surface. The $\hat{y}$ direction points vertically upwards, and $\hat{x}$ points horizontally. For each labeled points, describe the directions of the vectors $\vec{v}$, $\vec{F}_\text{gravity}$, and $F_\text{drag}$:
# * (a) On the way up after launch
# * (b) At the peak of its trajectory
# * (c) On the way back down.
# Don't worry about the magnitude of the vectors, just describe the directions.

# %% [markdown]
# ![projectile.png](attachment:projectile.png)

# %% [markdown]
# _At point (a) the vector_ :
# * $\vec{v}$ points:
# * $\vec{F}_\text{gravity}$ points:
# * $\vec{F}_\text{drag}$ points:

# %% [markdown]
# _At point (b) the vector_ :
# * $\vec{v}$ points:
# * $\vec{F}_\text{gravity}$ points:
# * $\vec{F}_\text{drag}$ points:

# %% [markdown]
# _At point (c) the vector_ :
# * $\vec{v}$ points:
# * $\vec{F}_\text{gravity}$ points:
# * $\vec{F}_\text{drag}$ points:

# %% [markdown]
# <strong><font color=blue>Problem 5.4: Will the magnitude of the drag force be larger at (a) or (b)?

# %% [markdown]
# _Write your answer here:_

# %% [markdown]
# <strong><font color=blue>Problem 5.5: What is the speed of an initially stationary ball after falling 2 meters (approximate height of the ball drop experiment) near the Earth's surface, ignoring drag? Use the code cell below to write a vector representing the final velocity as the variable `finalVelocity`.

# %%
#Use this cell to calculate the velocity of a ball after falling 2 meters

initialHeight = 2 # meters
gravityAccMag = 9.81 #meters/s^2, magnitude of acceleration due to gravity

    ### Edit this line ###
finalVelocity = ??? # in meters/s. This should be a vector.
    ### End edit ###
    
velocityMagnitude = np.linalg.norm(finalVelocity) #numpy.linalg.norm takes the magnitude of an array

print('The final velocity of a ball after falling 2 meters has a magnitude of {} meters/second'.format(finalVelocity))

# %% [markdown]
# <strong><font color=blue>Problem 5.6: Calculate the magnitude of the air drag force acting on a ball with this speed. You'll need to know the desnity of air in $\text{kg}/\text{m}^3$ (Problem 5.1), the value of $A$ for a sphere with radius $r=0.025 \ \text{m}$ and the value of $C$ for a sphere ($0.5$). The force due to drag is $F_\text{drag} = - \frac{1}{2}CA\rho|\vec{v}|v = -\frac{1}{2}CA\rho|\vec{v}|^2 \hat{v}$. We suggest using the first expression, with `np.linalg.norm(finalVelocity)` for $|\vec{v}|$

# %%
#Use this cell to calculate the magnitude of the drag force for a ball that has fallen 2 meters

v = finalVelocity # meters/s
r = 0.025 # meters
A = ??? #m^2
C = ??? #unitless
rho = 

b = ???

dragForce = 
gravityForce = 

dragMagnitude = np.linalg.norm(dragForce)
gravityMagnitude = np.linalg.norm(gravityForce)

ratio = ???

print('The ratio of the air drag force to gravity is {}'.format(ratio))

# %% [markdown]
# <strong><font color=blue>Problem 5.7: Calcualte the ratio of this magnitude to the magnitude of the gravitational force acting on the ball (assuming a mass of $75 \ \text{g}$).

# %% [markdown]
# _Write your answer here:_

# %% [markdown]
# <strong><font color=blue>Problem 5.8: Based on the result of problem 5.7, is it a valid assumption to ignore air resistance for this problem?

# %% [markdown]
# _Write your answer here:_

# %% [markdown]
# ## Extra Credit: Meteor Ablation (8 points)

# %% [markdown]
# We can make a very crude estimate of the altitude at which a meteor is vaporized by calculating the work done due to air drag in the upper atmosphere and comparing it to the heat required to vaporize a meteor sized object composed of iron. For simplicity, we will ignore the effects of heat transfer, radiative losses, and the mass of the meteor as a function of time.

# %% [markdown]
# Useful physical properties of Iron:
# * Density $\rho_\text{Fe} = 7.874$ in $\text{g}/\text{cm}^3$, near room temperature.
# * Molar Mass $\mu = 55.847$ in $\text{g}/\text{mol}$

# %% [markdown]
# <strong><font color=blue>Problem 5.9: Calculate mass of an iron spherical meteorite of radius $5 \ \text{m}$.

# %%
radius = 5
    ### Edit These Lines ###
density = ??? # kg/m^3

volume = ??? # in m^3

meteorMass = ??? # in kg
    ### End Edit ###
    
print('The mass of the meteor is {:.3e} kg.'.format(meteorMass))

# %% [markdown]
# Next, since the density of air changes as the meteor falls, we must take this into account when we write the force due to drag. The density of air at high altitudes can be modeled with an exponential decay:
#
# $\rho_{\text{air}}(h) = \rho_{\text{air},0} \cdot e^{(-h/H_n)}$
#
# where $\rho_{\text{air},0}$ is the standard room temperature density and $H_n = 10.4 \ \text{km}$ was found empirially.  We can define a function, **run the next cell to do so**.

# %%
def rho_air(height):
    H = 10400 # m
    rho = 1.1225 * np.exp(-height/H) # kg/m^3
    return rho

# %% [markdown]
# <strong><font color=blue> Problem 5.10: Complete the code below to define a function for the drag force in the upper atmosphere with a variable air density. You must find the cross sectional area `A` and the drag coefficient `b` in $F_\text{drag} = -\frac{1}{2} C A \rho_\text{air}(h) |\vec{v}| \vec{v} = -b(h) |\vec{v}| \vec{v}$ where $\rho_\text{air}(h)$ is the air density as a function of height.

# %%
    ### Begin Edit ###
# write the cross sectional area of your spherical meteor
A = ??? # in m^2
    ### End Edit ###
    
C = 0.5

def dragForce(height,vel):
            ### Begin Edit ###
        # Write the drag coefficient using the variable density rho_air(height) we defined before
        b = ???
            ### End Edit ###
    
        Fdrag = - b * vel * np.linalg.norm(vel)
    
        return Fdrag
    
def totalForce(height,vel):

        Ftotal = np.array([0,-9.81])*meteorMass + dragForce(height,vel)

        return Ftotal

# %% [markdown]
# <strong>Prior to vaporizing the iron will undergo many phase transitions. A simplified version of the specific heat and enthalpies of these transitions are written in the following code. Use the code with $Q = C\cdot m\cdot \Delta T$ to calculate the energy required to vaporize a meteorite using the mass you calculated in problem 5.9. For a simplified model, we assume:
# * The meteor begins at $0 \ \text{K}$ since it was in space.
# * $C = 35 \ \frac{\text{J}}{\text{mol}\cdot \text{K}}$ for $T \leq 1000 \text{K}$
# * $C = 55 \ \frac{\text{J}}{\text{mol}\cdot \text{K}}$ for $1000 \text{K} < T < 1100 \text{K}$
# * $C = 45 \ \frac{\text{J}}{\text{mol}\cdot \text{K}}$ for $T \geq 1100 \text{K}$
# * The latent heat of vaporization is roughly $350 \ \text{kJ}/\text{mol}$
# * The latent heat of fusion is roughly $14 \ \text{kJ}/\text{mol}$
# * The vaporization temperature of iron is roughly $2860 \text{K}$

# %% [markdown]
# <strong><font color=red> Run the code cell below to calculate the energy required to vaporize a meteor with the mass you calculated before. No editing requried.

# %%
molarMass = 55.847 / 1000# careful of units here


Clow = 35
Cmid = 55
Chigh = 45

dTlow = 1000
dTmid = 100
dThigh = 2860-1100

Qlow  = meteorMass/molarMass * Clow  * dTlow
Qmid  = meteorMass/molarMass * Cmid  * dTmid
Qhigh = meteorMass/molarMass * Chigh * dThigh

dHfus = 14000 # in J/mol
dHvap = 350000 # in J/mol

# Energy required for melting is the product of the latent heat (fusion) and moles
Qfus = dHfus * meteorMass / molarMass # in J

# Energy required for vaporization is the product of the latent heat (vaporization) and moles
Qvap = dHvap * meteorMass / molarMass # in J

Qtotal = Qlow + Qmid + Qhigh + Qfus + Qvap # should be in J

print('The total energy required to vaporize a meteor of mass {:.0f} kg with is {:.3} kJ'.format(meteorMass,Qtotal/1000))

# %% [markdown]
# In reality the specific heat profile as a function of temperature (and pressure) is more complex, but for our purposes this is enough.

# %% [markdown]
# The work done by drag can be found by integrating $W = - \int \vec{F} \cdot d\vec{s} = - b \int v^2 \hat{v} \cdot d\vec{s} = b \int |v|^3 dt$. Since we know the instantaneous velocity when using Euler's method, we can solve for the work done by drag as we solve for the position and velocity of the meteor. Each time step $dt$ we will do work $dW = b |v|^3 dt$.

# %% [markdown]
# <strong><font color=blue>Problem 5.11: Complete the code below to use your variable drag force to calculate the work done by drag as the meteor falls in to the atmosphere we will
# * (a) Define initial conditions. Assume it begins at a velocity of $20 \text{km/s}$ and at $h = 250 \ \text{km}$ above the atmosphere
# * (b) We will use Euler's method to calculate the velocity and position as a function of time.
# * (c) Calculate the work done by drag as the meteor falls and find the altitude at which it would ablate. We will also include an energy coefficient to try and account for the thermodynamic effects we ignored $\Lambda = 0.9$ since not all the work done by drag goes into heating the meteor.

# %% [markdown]
# <strong><font color=red> Code Task 5.1: Fill in the initial position (vector), `posInitial` and magnitude of the initial velocity (scalar), `velocityMagnitude` for <font color=blue> Problem 5.12a<font color=red>. We don't expect the meteor to fall straight down, so we introduce an angle $\theta$ or `theta` in the code to pick the angle at which the meteor falls. An angle of $-\pi/2$ would be straight down, for now we will pick a shallow angle $-\pi/8$.

# %%
# initial conditions
# velocity and position are vectors

    ### Edit this line ###
# The initial position, altitude (y direction)
posInitial = ??? # vector with 2 dimensions, in m
    ### End edit ###


    ### Edit this line ###
# The magnitude of the initial velocity, a scalar
velocityMagnitude = ??? # scalar in m/s
    ### End Edit ###
    
# theta is the angle the meteor makes with the horizon. We can start by sending it at a steep angle
theta = - np.pi/8
velInitial = np.array([np.cos(theta)*velocityMagnitude,np.sin(theta)*velocityMagnitude]) # vector, m/s

# Characteristic time
Tc = 30 # seconds

Ncycles = 10000
dt = Tc/Ncycles # seconds

timeArray = np.arange(0,Tc+dt,dt)
N = np.size(timeArray)

posArray = []
posArray.append(posInitial)
velArray = []
velArray.append(velInitial)

# %% [markdown]
# <strong><font color=red>Code Task 5.2: Fill in the appropriate arguments for the total force as a function of height and velocity we defined as `totalForce` from <font color=blue>Problem 5.10<font color=red> for <font color=blue>Problem 5.12b<font color=red>. You only need to edit one line, you must find the height and velocity from the vectors `posOld` and `velOld`.

# %%
#euler's method

for n in range(1,N):
    
    # t is the time elapsed, dt is a time step
    t = timeArray[n]
    
    # the position before updating
    # posOld is a (2) vector
    posOld = posArray[n-1]
    
    # the velocity before updating
    # velOld is a (2) vector
    velOld = velArray[n-1]
    
        ### Begin Edit ###
    # use the function dragForce(height,vel) we defiend earlier, using appropriate variables for height and vel
    # remember that the index [0] is the x value and the index [1] is the y value
    Ftotal = totalForce(???,???)
        ### End Edit ###
    
    # use euler's method to update
    a = Ftotal/meteorMass 
    
    velNew = velOld + a*dt
    
    posNew = posOld + velOld*dt
    
    velArray.append(velNew)
    posArray.append(posNew)

# %% [markdown]
# <strong><font color=red>Code Task 5.3: Code the expression $dW = \Lambda \cdot b |v|^3 dt$ for the variable `dW` below to integrate the work done by drag as the meteor falls. The `for` loop iterates over all times and stops when the work done by drag exceeds the energy required to vaporize the meteor.

# %%
W = 0

for n in range(N):
    
    posNow = posArray[n]
    velNow = velArray[n]
    
    b = 0.5 * C * A * rho_air(posNow[1])
    Lambda = 0.9
    
        ### Edit this line ###
    # use np.linalg.norm(v) to find the magnitude of the velocity
    dW = ??? #in J
        ### End Edit
    W += dW
    
    if W >= Qtotal:
        ablateTime = timeArray[n]
        ablateHeight = posArray[n][1]
        print('The meteor ablates after {:.4f} seconds at an altitude {:.0f} km'.format(ablateTime,ablateHeight/1000))
        break

# %% [markdown]
# ### <center> You're done! Submit your pre-lab per the following instructions

# %% [markdown]
# * Save this file with the pre-lab number and your uniqname to submit to canvas, e.g. `prelab05_ericgz.ipynb`.
# * Save the file as a html file. You can do this by opening the `File` tab on the top left corner of Jupyter, then select `Download as > html (.html)`
# * Submit both the .ipynb and .html files to canvas under the `Pre-Lab 5: Two Dimensional Motion with Drag` assignment.
