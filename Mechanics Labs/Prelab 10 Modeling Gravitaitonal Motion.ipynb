# %% [markdown]
# # Prelab 10: Modeling Gravitational Motion

# %% [markdown]
# _Name:_

# %%
import numpy as np

# %% [markdown]
# <strong>The following GIF repicts an object in circular motion with a relative position vector $\vec{r}$ and velocity vector $\vec{v}$.

# %% [markdown]
# ![CircularMotion.gif](attachment:CircularMotion.gif)

# %% [markdown]
# <strong><font color=blue>Problem 10.1: In which direction does the gravitational force act? Hint: you can use parallel or antiparallel to $\vec{r}$ or $\vec{v}$ in your response

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=blue>Problem 10.2: During its circular orbit, in a very small amount of time dt, a planet moves an infinitesimal amount $d\vec{s}$ in the same direction as $\vec{v}$ in at that moment. What is the work done on the planet by the gravitational force? Recall work done by gravity is calculated as $dW = \vec{F} \cdot d\vec{s}$.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=blue>Problem 10.3: Will the object's kinetic energy change as it moves in a circular orbit?

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=blue>Problem 10.4: Use the equation for acceleration during circular motion $|F| = m|\vec{v}|^2/|\vec{r}|$ and the equation for graviational acceleration to express the speed if an object in circular motion in terms of the large mass $M$ (red in the GIF), the small mass $m$ (blue in the GIF), the magnitude of the relative position $|\vec{r}|$, and Newton's constant $G$.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=blue>Problem 10.5: From the speed you found in problem 10.4, find a characteristic time of orbital motion in terms of the same variables. Hint: with a speed we can find a related time using $v = d/t$ and solve for $t$ with the appropriate $d$ (distance) and $v$ (velocity/speed).

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# ### <center> You're done! Submit your pre-lab per the following instructions

# %% [markdown]
# * Save this file with the pre-lab number and your uniqname to submit to canvas, e.g. `prelab10_ericgz.ipynb`.
# * Save the file as a html file. You can do this by opening the `File` tab on the top left corner of Jupyter, then select `Download as > html (.html)`
# * Submit both the .ipynb and .html files to canvas under the `Pre-Lab 10: Modeling Gravitational Motion` assignment.
