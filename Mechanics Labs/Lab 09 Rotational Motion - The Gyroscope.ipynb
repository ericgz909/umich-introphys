# %% [markdown]
# # Lab 9: Rotational Motion - The Gyroscope

# %% [markdown]
# _Group Members_ :

# %% [markdown]
# # <font color=red>Safety First!
#
# - **If you have long hair, please secure it away from your face so that there is no risk of your hair becoming tangled in the spinning gyroscopes.**
#     - If you need a hair tie, please ask your GSI!
# - **Please wear safety glasses whenever spinning up the gyroscopes.**
# - **Be careful not to drop the gyroscopes. They are heavy!**

# %% [markdown]
# # Using the Gyroscope
#
#
# **Historical note:** *The gyroscopes originally used in these laboratories were designed about 30 years ago by Professor Richard Crane, a physicist who made some exquisitely precise measurements of the gyromagnetic ratio of the electron, confirming our understanding of quantum electrodynamics. The sculpture on the south side of the courtyard between Randall and West Hall commemorates this important contribution to 20th-century physics.*
#
# The equipment we will use in this experiment has a more modern design with a few more safety considerations; however, some precautions are still in order. Please take note of the following:
#
# 1. Be careful with the gyroscopes. When fully spun up, the gyroscopes used in this laboratory store almost 500 J of kinetic energy, equivalent to a baseball moving at 180 mph. They are also somewhat heavy, so you do not want to drop them on your feet.
# 2. A small electric motor with a 1-inch-diameter felt wheel (Dremel tool) is provided to spin up the gyroscope to a high angular velocity. To spin up the gyroscope, turn on the motor and bring the edge of the felt wheel into contact with the rim of the rotor, as shown below.
#
# ![dremel.png](attachment:dremel.png)
#
# 3. Keep a very light, steady pressure on the felt wheel while spinning up the gyroscope. **Note that pressing too hard will burn the surface of the felt** (and will actually slow the rotor’s spin).
# 4. Keep your eyes away from the line of contact between the felt wheel and the rotor rim. Small bits of the felt will flake off and may irritate your eyes. Because of this, **all** group members **must** wear safety goggles when spinning up the rotor.
# 5. It will take a couple of minutes to bring the rotor speed above 3,200 RPM, which is the speed we will need for these experiments.
# 6. If you notice that the diameter of your felt disk is significantly less than 1 inch or that it exhibits significant burn marks around its edge, notify your instructor.
# 7. To stop the gyroscope from spinning, gently touch a piece of paper towel to the rotor rim to bring it slowly to a halt.
#
# There is a piece of reflective tape attached to one side of the gyroscope rotor. By aiming the beam of a small *photo tachometer* at this tape while the gyroscope is spinning, you can measure its angular speed in RPM. An illustration of this technique is shown in below.
#
# ![tachometer.png](attachment:tachometer.png)
#
# The tachometer should be held a few inches from the rotor so that it illuminates the reflective strip as shown above. Aim the beam of light at an angle of 30$^\circ$ or so from the normal to the rotor surface. This enhances the contrast between the light reflected from the reflective strip and stray light from the rest of the rotor surface. The angular velocity in RPM is reported by the display.

# %% [markdown]
# # Part One: Angular Momentum and the Spinning Chair
#
# **Note: There is only one setup for this experiment in each classroom.** If the chair is in use, please move on to the next part until it is availiable. You are not required to do this before moving on to the rest of the lab, but should complete it before the end of class.
#
# The angular momemtum of any system remains constant, so long as no external torque acts on this system. **We will define the _system_ collectively as: the rotating part of the chair, the person sitting on it, and the gyroscope they are holding.**
#
# ### Experiment:
#
# 1. Have one lab member sit on the spinning chair.
#
# 2. **Other lab member(s):** spin up the gyroscope to at least 3,200 RPM, and determine the direction of its angular momentum using the right-hand-rule.
#
# 3. Hand the gyroscope to the lab member sitting in the chair, oriented with its _angular momentum vector_ pointing upward, as shown below.
# ![handheld.png](attachment:handheld.png)
#
# 4. **Person in the chair:** be sure that your feet are not touching the ground. This ensures that there are no external torques acting on the system.
#
# 5. Then according to the conservation law for angular momentum, the magnitude and direction of the system's angular momentum should remain constant.
#
# 6. **Person in the chair:** quickly (and safely) flip over the gyroscope, so that its _angular momentum vector_ points downward. You will feel the gyroscope fighting you!
#
# **<font color=green>Note: For the online version of this course, you can find a video of an instructor performing the experiment [here](https://drive.google.com/file/d/122CAQjcPlBq3rcSi_c68MPex6ioTByFT/view?usp=sharing).**

# %% [markdown]
# **<font color=A07A06>Problem 9.1: What was the direction of the gyroscope's _angular momentum vector_ before the flip? What about after the flip?**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# **<font color=A07A06>Problem 9.2: After flipping the gyroscope, what other parts of the system (chair, person, etc.) had angular momentum? What were the directions of those _angular momentum vectors_ (up or down)?**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# **<font color=A07A06>Problem 9.3: Why did the person in the chair begin to spin when they flipped the gyroscope? Explain using the concept of _conservation of angular momentum_.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# # Part Two: Creating a Physical Model of Gyroscopic Precession
#
# When handling the rapidly spinning gyroscopes, you may have noticed that they behave oddly, and it feels as though the gyroscope is fighting you as you maniplulate it. In this section, we will create a model for this behavior, termed _gyroscopic precession_.
#
# ### Setup:
#
# Mount the gyroscope in the cradle assembly as shown below. Insert the longer end of the shaft into the shorter sleeve, so that the gyroscope is level. Insert the pins to secure the assembly. The gyroscope is now free to pivot about its center of mass.
#
# ![gyroscope_cradle.jpg](attachment:gyroscope_cradle.jpg)
#
# ### Experiment:
#
# 1. Spin up the gyroscope in the direction such that its _angular momentum vector_ ($\vec{\mathrm L}$) points to the right (in the $+\hat {\mathrm x}$ direction as defined in the picture above). The angular velocity should be at least 3,200 RPM, though the exact number is not important. Periodically throughout the experiment, you will need to spin up the gyroscope again.
#    * To determine the direction of the _angular momentum vector_ , curl the fingers of your right hand in the direction of the flywheel's rotation, and your thumb will point in the $\vec{\mathrm L}$.
#
# 27. Now, use a pencil/pen to apply forces to the ends of the gyroscope shaft. Play around a bit. **Notice that the gyroscope shaft moves _not_ in the direction you push it, but rather in a direction $90^\circ$ from the applied force!** Now, we would like to discuss the _change in angular momentum_ , $\Delta \vec{\mathrm L}$, caused by these applied forces. For example, if the **right** end of the shaft (which defines the direction of angular momentum $\vec{\mathrm L}$) moves **upward**, we could say that $\Delta \vec{\mathrm L}$ points in the $+\hat{\mathrm y}$ direction.
#
# 4. **To apply torques in a consistent manner, and discuss the results mathematically, let's think in terms of the coordinate system shown in the picture above.** We need to know the direction of the applied force, and we also need to know _where_ the force acts on the gyroscope shaft. Let's designate the applied force as $\vec{\mathrm F}$, and the radius vector from the origin to the location of the applied force as $\vec{\mathrm r}$. **For example,** if we press downward on the right end of the shaft, we could say that $\vec{\mathrm r}$ points in the $+\hat{\mathrm x}$ direction, and $\vec{\mathrm F}$ points in the $-\hat{\mathrm y}$ direction.
#
# 5. Now, spin up the gyroscope again and perform the steps below.
#
# **<font color=green>Note: For the online version of this course, you can find a video of an instructor performing the experiment [here](https://drive.google.com/file/d/1EmRYEsyJxYFecUymOZgMXxljnCs6f2dH/view?usp=sharing).**

# %% [markdown]
# **<font color=A07A06>Problem 9.4: Use a pencil to press the <font color= #6e2f8c > _right_ <font color=A07A06> end of the gyroscope shaft <font color= #6e2f8c > _away_ <font color=A07A06> from you. In terms of $\hat{\mathrm x}$, $\hat{\mathrm y}$, and $\hat{\mathrm z}$, what are the directions of $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$?**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# **<font color=A07A06>Problem 9.5: Use a pencil to press the <font color= #6e2f8c > _left_ <font color=A07A06> end of the gyroscope shaft <font color= #6e2f8c > _away_ <font color=A07A06> from you. In terms of $\hat{\mathrm x}$, $\hat{\mathrm y}$, and $\hat{\mathrm z}$, what are the directions of $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$? (Note that $\Delta \vec{\mathrm L}$ is in the direction of the displacement of the <font color= #6e2f8c > _right_ <font color=A07A06> end of the gyroscope shaft, even if you are applying the force on the <font color= #6e2f8c > _left_ <font color=A07A06> end of the shaft.)**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# **<font color=004D40>Problem 9.6: Use a pencil to press the <font color= #6e2f8c > _right_ <font color=004D40> end of the gyroscope shaft <font color= #6e2f8c > _upward_ <font color=004D40>. In terms of $\hat{\mathrm x}$, $\hat{\mathrm y}$, and $\hat{\mathrm z}$, what are the directions of $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$?**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# ### Analysis:
#
# Now we would like to express a mathematical relationship between $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$. In all the questions above, hopefully you found that $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$ are all _orthogonal_ ; that is, one points along $\hat{\mathrm x}$, one along $\hat{\mathrm y}$, and one along $\hat{\mathrm z}$. This may remind you of the right-hand-rule for cross-products, as in
#
# $$\vec{\mathrm a} \times \vec{\mathrm b} = \vec{\mathrm c}.$$

# %% [markdown]
# **<font color=004D40>Problem 9.7: Write down a relationship of the form $\vec{\mathrm c} \propto \vec{\mathrm a} \times \vec{\mathrm b}$ for the quantities $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$. Ensure that the relationship is consistent with the directions and $\pm$ signs of $\vec{\mathrm r}$, $\vec{\mathrm F}$, and $\Delta \vec{\mathrm L}$ as found in Questions 4-6. (Note that you should write a _proportionality_ $\vec{\mathrm c} \propto \vec{\mathrm a} \times \vec{\mathrm b}$, not an equality, since we have not considered the _magnitudes_ of any quantities, only the directions.)**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# # Cumulative Assessment Task: Precession Due to Gravity
#
# Gyroscopes exhibit a particularly odd presession behavior when suspended by one _end_ of the shaft. To see this, mount the gyroscope in the assembly as shown below. Secure the shaft in place by inserting the pin. Note that the gyroscope is free to swivel downward until it hits the table. Support the other end of the shaft using the hinged stand/flap.
#
# ![suspended.png](attachment:suspended.png)
#
# Now spin up the gyroscope to 3,200 rpm, and then quickly flip the hinged stand downward. Instead of falling to the table, the gyroscope shaft precesses in a circle! Nothing is supporting the free end of the gyroscope shaft, yet it remains suspended in the air!
#
# ### Creating a Physical Model:
#
# To model this bizarre behavior, we will need to carefully draw some vector diagrams. We will first work on model of what is going.  You will be asked to indicated directions of various vectors, and you may want a scratch piece of paper to draw the vectors out to help you visualize.  This section will walk you through the equation derivation you will need.

# %% [markdown]
# Let's begin by defining a coordinate system for our experimental setup. Here, $\hat{\mathrm z}$ is the vertical. Compare the experimental setup below to the setup on the lab bench.
#
# **<font color=green> Note: For the online version of this course, compare this figure to the figure given of the lab setup above.**
#
# ![gyroscope-1.png](attachment:gyroscope-1.png)
#
# Gyroscope experimental setup, as viewed from above. The gyroscope is suspended solely by the pivot in the center. The flywheel rotates rapidly in the direction shown by the red arrow, and the axle is free to swivel about the pivot.

# %% [markdown]
# Now, let's zoom in on the important part... See the figure below. We would like to look at the torque acting on the gyroscope due to the force of gravity. The torque about the pivot point is given by $\vec{\mathrm \tau} = \vec{\mathrm r} \times \vec{\mathrm F}$ where $\vec{\mathrm r}$ is the vector from the pivot to the center-of-mass, and $\vec{\mathrm F}$ is the force due to gravity.
#
# We have already drawn $\vec{\mathrm r}$ and $\vec{\mathrm F}$ in the figure below. **Now, determine the direction of the torque vector using the right-hand-rule for cross products, along with the torque equation given above.**
#
# ![gyroscope-2.png](attachment:gyroscope-2.png)
#
# Gyroscope flywheel and axle. The pivot is the coordinate origin.

# %% [markdown]
# **<font color=004D40>Problem 9.8:  Indicate the torque vector in the figure above.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# We will now think in terms of angular momentum. Refer to the figure below.
#
# ![gyroscope-3.png](attachment:gyroscope-3.png)
#
# The flywheel rotates rapidly in the direction shown by the red arrow.
#
# The rapidly rotating flywheel has some angular momentum $\vec{\mathrm L}$. **Find the direction of this angular momentum using the right-hand-rule for angular quantities.** (This is a different right-hand-rule than that for cross products.)

# %% [markdown]
# **<font color=004D40>Problem 9.9:  Indicate this angular momentum vector from the figure above, with its tail at the pivot point.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# Now we would like to investigate how the angular momentum vector changes over time. We can write Newton's second law in angular form as $\vec{\mathrm \tau} = \dfrac{\mathrm{d} \vec{\mathrm L}}{\mathrm{d} t}$, or equivalently, $\mathrm{d} \vec{\mathrm L} = \vec{\mathrm \tau} \cdot \mathrm{d} t$.
#
# Thus, we have an infinitesimal change in angular momentum, $\mathrm d \vec{\mathrm L}$, in the same direction as the torque vector $\vec{\mathrm \tau}$. But we already know the direction of the torque vector from the figure two figures above! Thus, we also know the direction of $\mathrm{d} \vec{\mathrm L}$.

# %% [markdown]
# **<font color=004D40>Problem 9.10:  Indicate this $\mathrm d \vec{\mathrm L}$ vector from the figure above, with its tail at the head of the $\vec{\mathrm L}$ vector.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# Then the new angular momentum vector after some infinitesimal time $\mathrm{d}t$ is $\vec{\mathrm L}^\prime = \vec{\mathrm L} + \mathrm{d}\vec{\mathrm L}$.

# %% [markdown]
# **<font color=1E88E5>Problem 9.11:  Indicate this $\vec{\mathrm L}^\prime$ vector from the figure above.**
#
# If you have drawn out the vectors, question 9, 10, and 11 should make a right triangle.

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# Label the angle between $\vec{\mathrm L}$ and $\vec{\mathrm L}^\prime$ as $\mathrm{d}\theta$.
#
# Now, thinking of the triangle formed by $\vec{\mathrm L}$, $\vec{\mathrm L}^\prime$, and $\mathrm{d}\vec{\mathrm L}$, write down $\tan (\mathrm{d}\theta)$ in terms of the magnitudes $L$ and $\mathrm{d}L$.

# %% [markdown]
# **<font color=1E88E5>Problem 9.12:  Indicate $\tan (\mathrm{d}\theta)$ in terms of the magnitudes $L$ and $\mathrm{d}L$**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# Using the relationship $\tan(\mathrm{d}\theta) = \mathrm{d}\theta$ _(which comes from a Taylor series expansion of $\tan x$),_ determine a relationship between $\mathrm{d}\theta$, $L$, and $\mathrm{d}L$.

# %% [markdown]
# **<font color=1E88E5>Problem 9.13:  Indicate $\mathrm{d}\theta =$ in terms of the magnitudes $L$ and $\mathrm{d}L$**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# **<font color=1E88E5>Problem 9.14:  Re-write question 13 by substituting $\mathrm{d L} = \tau \cdot \mathrm{d}t$.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# Divide through by $\mathrm{d}t$ to get $\dfrac{\mathrm{d}\theta}{\mathrm{d}t}$.  But $\dfrac{\mathrm{d}\theta}{\mathrm{d}t}$ is just the precession rate $\Omega$ of the gyroscope!

# %% [markdown]
# **<font color=1E88E5>Problem 9.15:  Determine $\Omega \equiv \dfrac{\mathrm{d}\theta}{\mathrm{d}t} =$**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# In the setup we're considering here, the torque $\tau$ is due to the force of gravity. Thus, $\tau = r F = r m g$, where $r$ is the distance from the gyroscope shaft pivot to the center-of-mass of the gyroscope, and $m$ is the mass of the gyroscope assembly. Furthermore, the angular momentum of the gyroscope flywheel is given by $L = I \omega$, where $I$ is the moment of inertia of the gyroscope flywheel, and $\omega$ is the angular velocity of the flywheel.

# %% [markdown]
# **<font color=D81B60>Problem 9.16: Write down a formula for the gyroscopic precession rate $\Omega$, as determined from the above derivation.  This final equation should have $r$, $m$, $g$, $I$, and $\omega$.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# ### Experiment:
#
# In this section, we will empirically test the model we've built in the section above. Two separate angular velocities will need to be measured for this exercise: the _rotor speed_ $\omega$ and the _precession rate_ $\Omega$. We will measure $\omega$ using the _photo tachometer_ , and we will measure $\Omega$ via fitting in Tracker.
#
# 1. Mount the gyroscope in the vertical stand as shown in the above image by placing the long end of the gyroscope shaft in the fork on the stand using the retainer pin.
# 1. Spin up the gyroscope to at least 3200 RPM using the Dremel tool.
# 1. Measure the angular velocity of the rotor using the photo tachometer and record this value in the table below.
# 1. Immediately after measuring the angular velocity, release the free end of the gyroscope from the stand and start taking a top side video.
# 1. Immediately after you are finished taking your data video, carefully grab the gyroscope and take another measurement of the rotor’s angular velocity, and record this value in the table below.
# 1. Use Tracker to analyze (auto track and fit the data) the video you took to determine the precession rate of the gyroscope.
# 1. Spin up the gyroscope again and repeat this procedure for two more trials.
# 1. We will now measure the torque due to gravity. Stop the rotor from spinning. Hook ths spring scale into the hole at the free end of the gyroscope shaft. Raise/lower the spring scale until the shaft lies level. Record the force measured by the scale. Use this measured force and its distance from the pivot point to calculate the torque.
#
#
# <strong><font color=green> Note: For the online version of this course, these videos will be given to you. You can find a demonstration (not for tracker use) video [here](https://drive.google.com/file/d/16ko3SgxgNlBbvlEKn3qrlARCtbDCdVx6/view?usp=sharing) to give you an idea of the experimental setup.
# * [Experiment 3 Trial 1](https://drive.google.com/file/d/18dviepXof5jiUAgwNRRgRbof8t14Jl2a/view?usp=sharing)
# * [Experiment 3 Trial 2](https://drive.google.com/file/d/1Dpf0NSHdZR6coUrq6pKZzXgrgSVS-M9A/view?usp=sharing)
# * [Experiment 3 Trial 3](https://drive.google.com/file/d/1fvKrkqb0EXVgGX5p1miyqNFK_TxHWrsG/view?usp=sharing)

# %% [markdown]
# **<font color=D81B60>Problem 9.17: Complete the data table below.**

# %% [markdown]
# Trial 1:
#
# | Parameter                         |          Value         |       Units        |
# | ---------                         |     --------------     |     ---------      |
# | Angular velocity $\omega$ before  |                3350    |        RPM         |
# | Angular velocity $\omega$ after   |                3100    |        RPM         |
# | Angular velocity $\omega$ (mean)  |    [Put value here]    |        RPM         |
# | Angular velocity $\omega$ (mean)  |    [Put value here]    |       rad/s        |
# | Precession rate $\Omega$          |    [Put value here]    |  [Put units here]  |
#
#
# Trial 2:
#
# | Parameter                         |          Value         |       Units        |
# | ---------                         |     --------------     |     ---------      |
# | Angular velocity $\omega$ before  |                3600    |        RPM         |
# | Angular velocity $\omega$ after   |                3200    |        RPM         |
# | Angular velocity $\omega$ (mean)  |    [Put value here]    |        RPM         |
# | Angular velocity $\omega$ (mean)  |    [Put value here]    |       rad/s        |
# | Precession rate $\Omega$          |    [Put value here]    |  [Put units here]  |
#
#
# Trial 3:
#
# | Parameter                         |          Value         |       Units        |
# | ---------                         |     --------------     |     ---------      |
# | Angular velocity $\omega$ before  |                3600    |        RPM         |
# | Angular velocity $\omega$ after   |                3230    |        RPM         |
# | Angular velocity $\omega$ (mean)  |    [Put value here]    |        RPM         |
# | Angular velocity $\omega$ (mean)  |    [Put value here]    |       rad/s        |
# | Precession rate $\Omega$          |    [Put value here]    |  [Put units here]  |

# %% [markdown]
# **<font color=blue>Problem 9.18: Complete the table below, including calculation of the torque. Show your work!**

# %% [markdown]
# | Parameter                         |          Value         |       Units        |
# | ---------                         |     --------------     |     ---------      |
# | Distance from Pivot to Measurement Point (Red Label) |    0.19        |       meters       |
# | Force on spring scale             |    4.2                 |  Newtons  |
# | Torque due to gravity             |    [Put value here]    |  [Put units here]  |
#
#
# **<font color=green> Note: For the online version of this course, you will be given the force on spring scale value.**

# %% [markdown]
# **<font color=red>Code Task 9.1: Input the values from question 18 into the code below.**

# %%
distance = 0.19  # meters
force = 0.00     # enter your measurement
torque = 0.00    # do your calculation here

print("Parameter\t\t\t\t | Value\t| Units")
print("-"*60)
print("Distance from pivot to measurement point |", distance, "\t| meters")
print("-"*60)
print("Force on Spring Scale\t\t\t |", force, "\t| N")
print("-"*60)
print("Torque due to gravity\t\t\t |", torque, "\t| N m")

# %% [markdown]
# **<font color=red>Code Task 9.2: Calculate $I$, the moment of inertia of the gyroscope rotor. <font color=red>The rotor's mass is labeled on the rotor.**

# %%
momentI = 0.00  # do your calculation here

print(momentI, "kg m^2")

# %% [markdown]
# **<font color=red>Code Task 9.3: Calculate the theoretical precession rate using question 16, along with torque $\tau$, average angular velocity $\omega$, and moment of inertia $I$.**

# %%
rateOmega = 0.00  # do your calculation here

print(rateOmega, "rad/s")

# %% [markdown]
# **<font color=D81B60>Problem 9.19: Compare the calculated and meaured values for precession rate $\Omega$.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# **<font color=D81B60>Problem 9.20: Discuss the difference between your angular velcity $\omega$ and your precession rate $\Omega$.  Make sure to discuss the difference in what they physically represent, and compare the order of magnitude of their values.**

# %% [markdown]
# _Double click this cell to begin editing. Write your answer here._

# %% [markdown]
# ### <center>You're done! Submit your lab per the following instructions.<font color=white><#!S!#>

# %% [markdown]
# * Save this file with the lab number and group number to submit to canvas, e.g. `group01_lab02.ipynb`.
# * You only need to submit one file as a group to the canvas assignment and it will count for all group members.
# * The group recorder should still send the worksheet to their group members so they have a copy.
# * Save the file as a html file. You can do this by opening the `File` tab on the top left corner of Jupyter, then select `Download as > html (.html)`
# * Submit both the .ipynb and .html files to canvas under the `Lab 9: Rotational Motion - Gyroscope` assignment.
