# %% [markdown]
# # <center>Lab 1: Electric Fields

# %% [markdown]
# _Name:_

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# %matplotlib inline

# %% [markdown]
# # <font color=Black>Part One: Parallel Plates</font>

# %% [markdown]
# ## Mapping the Electric Field and Equipotential Lines</font>

# %% [markdown]
# <strong><font color=green>Follow the link https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html and use the simulation to construct two lines of charges. Use the sensor and equipotential tool to explore the configuration.

# %% [markdown]
# ![phet_1.png](attachment:phet_1.png)

# %% [markdown]
# <strong><font color=green>The sensor tool is a test charge at the yellow point, with the red line indicating the direction and magnitude of the acceleration.

# %% [markdown]
# ![phet_3.png](attachment:phet_3.png)

# %% [markdown]
# <strong><font color=green>The equipotential tool allows you to select a voltage a point in the simulation and draws an equipotential line of that voltage.

# %% [markdown]
# ![phet_2.png](attachment:phet_2.png)

# %% [markdown]
# **<font color=Green>Alternatively, look at the electric field and equipotential lines drawn by other students to help answer the following questions**

# %% [markdown]
# ![pic1.png](attachment:pic1.png)

# %% [markdown]
# ![pic2.png](attachment:pic2.png)

# %% [markdown]
# ![pic3.png](attachment:pic3.png)

# %% [markdown]
# <strong><font color=Blue> Problem 1.5: Imagine placing a small positive charge in the tray located on top of one of the electric field lines. In which direction would it move, towards the <font color=black>negative electrode</font><font color=blue> or </font><font color=red>positive electrode</font><font color=blue>? What if the charge were negative?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.6: Imagine inserting a third metal bar centered between the two existing bars. How would the voltage and equipotential lines change if we set the voltage of this bar to $5$ V by applying a third lead with the appropriate voltage? What about if this centered bar were set to $7$ V?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.7: In the same scenario as the previous question, how would the electric field lines change? Respond for both $5$ V and $7$ V cases.</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.8: What difference do you notice between field lines near the center of the plate versus field lines near the edge of the plate? Consider both magnitude and direction. Explain the physical reasoning behind these differences. _Hint: Consider the distribution of charges on the bar._</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# ## <font color=Black>Path Dependence When Measuring Voltage</font>

# %% [markdown]
# **<font color=Purple> Directions: Follow steps 14-17 to measure the voltage along two different paths, then answer the following questions.</font>**

# %% [markdown]
# <strong><font color=green>[Online] These measurements were performed for you and are tabulated below. Use the results to answer the question.

# %% [markdown]
# <strong><font color=Blue> Problem 1.9: Record your measurements for the $\Delta V$ readings in the table below.</font></strong>

# %% [markdown]
# <table style="table-layout: fixed;"> <tbody>  <tr> <td>     </td> <td> Measurement One [V] </td> <td> Measurement Two [V] </td> <td> Measurement Three [V] </td> <td> Measurement Four [V] </td> <td> Measurement Five [V] </td> <td> Measurement Six [V] </td> </tr> <tr> <td> Path 1 </td> <td> 0.992 </td> <td> 1.026 </td> <td> 0.978 </td> <td> - </td> <td> - </td> <td> - </td> </tr> <tr> <td> Path 2 </td> <td> 0.500 </td> <td> 0.499 </td> <td> 0.450 </td> <td> 0.545 </td> <td> 0.538 </td> <td> 0.582 </td> </tr> </tbody> </table>

# %% [markdown]
# <strong><font color=Blue> Problem 1.10: Do the $\Delta V$ readings that you recorded add up the the difference between the equipotentials?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.11: Try following a different path between the equipotentials, starting at the same point on the $4$ V equipotential and ending at the same point on the $7$ V equipotential. Do the $\Delta V$ readings that you recorded add up the the difference between the equipotentials?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.12: Does $\Delta V$ depend on what path you take from the $4$ V to the $7$ V equipotential lines?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # <font color=Black>Part Two: Wedge and Plate</font>

# %% [markdown]
# **<font color=Purple> Directions: Follow steps 1-3 in the lab manual to analyze the wed and plate setup.</font>**

# %% [markdown]
# <strong><font color=green>[Online] If you are using the simulation tool, recreate the wedge and plate to help answer the questions that follow.

# %% [markdown]
# ![wedge_labelled.png](attachment:wedge_labelled.png)

# %% [markdown]
# <strong><font color=Blue> Problem 1.13: Is the electric field at point A much larger, about equal to, or much smaller than the field at B? What does this say about the distribution of charges on the wedge?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.14: Is there a large difference between the electric field at points C, D, and E? Near the long bar it is similar to having an infinite plane of charge.</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # <font color=Black>Part Three: Electric Field inside the Inner Ring</font>

# %% [markdown]
# <strong><font color=green>[Online] If you are using the simulation tool, see if you can recreate the concentric circle configuration.

# %% [markdown]
# ![pic4.png](attachment:pic4.png)

# %% [markdown]
# ## <font color=Black>Internal Electric Field</font>

# %% [markdown]
# **<font color=Purple> Directions: Follow steps one and two to measure the electric field inside of the concentric rings.</font>**

# %% [markdown]
# <strong><font color=green>[Online] Info: The electric field is constant inside the inner ring.

# %% [markdown]
# <strong><font color=Blue> Problem 1.15: Describe the behavior of the electric potential inside the small inner circle. What does this imply about the electric field inside the small inner circle?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# ## <font color=Black>Electric Field Between the Rings</font>

# %% [markdown]
# **<font color=Purple> Directions: Follow steps four through five in the lab manual to record the electric field between the two rings. </font>**

# %% [markdown]
# <strong><font color=Blue> Problem 1.16: Use your measurements of the voltage and the magnitude of the electric field at the specified points to complete the table below. Note that $r$ is to be measured from the center of the entire configuration, not from the outside of the small circle.</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <table style="table-layout: fixed;"> <tbody>  <tr> <td> Distance from center $r$ [cm] </td> <td> $4.5$ </td> <td> $5.5$ </td> <td> $6.5$ </td> <td> $7.5$ </td> <td> $8.5$ </td> <td> $9.5$ </td> </tr> <tr> <td> Electric Field [V/cm] </td> <td> 1.64 </td> <td> 1.30 </td> <td> 1.09 </td> <td> 0.92 </td> <td> 0.82 </td> <td> 0.73 </td> </tr> <tr> <td> Potential [V] </td> <td> 7.07 </td> <td> 5.67 </td> <td> 4.47 </td> <td> 3.41 </td> <td> 2.50 </td> <td> 1.75 </td> </tr> </tbody> </table>

# %% [markdown]
# <strong><font color=Blue> Problem 1.17: To plot your data,  label your axes and plots with appropriate titles. The plotting code has been completed for you with the exception of the labels. Read the comment notes carefully to understand how the code works.</font></strong>

# %%
# here we write an array corresponding for the radii of our measurements
radius = np.array([4.5,5.5,6.5,7.5,8.5,9.5])


# the table has two rows, here we give names to each row in the table to make our plots
    ### Edit These Arrays ###
e_field = np.array([])
voltage = np.array([])
    ### End Edit ###

    ###  Edit These Titles  ###
e_field_plot_title = 'my_title' 
e_field_plot_xaxis = 'my_xaxis'
e_field_plot_yaxis = 'my_yaxis'

voltage_plot_title = 'my_title'
voltage_plot_xaxis = 'my_xaxis'
voltage_plot_yaxis = 'my_yaxis'
    ###  End Edit  ###

    
# Code to plot Electric Field and Voltage
# this command, plt.figure() tells python to create a figure where we can plot. Think of it as a canvas for our plots.
plt.figure(1,figsize = [16,6])

# this command, plt.subplot(nml) is for creating subplots in a figure. here, n=1 is the number of rows, 
# m=2 is the number of columns, and l=1 is the an index for the lines that follow.
# setting l=1 is telling python that you want to plot in the first subplot of the figure
plt.subplot(121)
# this plots the inverse radius along the x axis and the electric field along the y axis. 
# 'go' is two instructions, 'g' means green and 'o' means dots; the markers for 
# this data will be green dots
plt.plot(1./radius,e_field,'go')
# the next three commands places the labels we previously defined onto the plot
plt.title(e_field_plot_title)
plt.xlabel(e_field_plot_xaxis)
plt.ylabel(e_field_plot_yaxis)

# notice we call plt.subtplot(nml) again with the same n and m but a different l. this means we are moving
# from the previous l=1 plot into the l=2 plot space,
# therefore the commands that follow will be for a second, separate plot
plt.subplot(122)

# we now plot radius vs. voltage with 'bo' blue dot markers
plt.plot(radius,voltage,'bo')
# since our hypothesis says that voltage goes like log of the radius, we change the radius scale to a log scale
plt.xscale('log')
# again, input out plot labels
plt.title(voltage_plot_title)
plt.xlabel(voltage_plot_xaxis)
plt.ylabel(voltage_plot_yaxis)
    
# display the plot here
plt.show()

# %% [markdown]
# ## <font color=Black>Coding a Fit to the Theoretical Model</font>

# %% [markdown]
# <strong><font color=Blue> Problem 1.18: It is predicted from theory that for this configuration we should find $|\vec{E}|=\alpha/r$ and $V=\beta \ln r$. Use the following code cells to perform a fit to your data and test these hypotheses. These cells will produce plots for submission.</font></strong>

# %% [markdown]
# **<font color=Red>Coding Notes: We will use scipy's `optimize.curve_fit` to find $\alpha$ and $\beta$. The method `curve_fit` takes a minimum of three arguments:**
#
# * `x_data` **data for the independent variable**
#
# * `y_data` **data for the dependent variable**
#
# * **a function `f` where `y_data = (x_data, *parameters)` with an arbitrary number of fit parameters `parameters`. For example, if we fit to a line `y=mx+b` and our fit parameters are `m` the slope and `b` the bias.**
#
# **Once called, `curve_fit` will return two objects, a list of the optimized parameters `popt` and the covariant matrix `pcov`. For our purposes, we only care about the optimized parameters.**
#
# **If we have data `x_data` i.e. the radius and `y_data` i.e. voltage or electric field measurements, all we need to do is write a function `f` that corresponds to our hypothesis of the relationship between `x_data` and `y_data` and pass `f` to `curve_fit`. This procedure is done for you, in this lab. We will use it many times throughout the course.**
# </font>**

# %%
def EField(r,alpha, C):
    ###  Edit the following line. What is E?  ###
    # Be sure to add constant C to equation
    #E =
    ###  End Edit  ###
    return E

def Potential(r, beta, C):
    ###  Edit the following line. What is V?  ###
    # Be sure to add constant C to equation
    # Since our hypothesis for the potential includes a log, we can use the numpy function
    ## np.log(r) in our Potential function. ##
    #V =
    ###  End Edit  ###
    return V

#Now we call curve_fit which has been imported in the initialization sell as sp_cfit

paramsE, efcov = curve_fit(EField, radius, e_field) 
paramsV, efcov = curve_fit(Potential, radius, voltage)

alpha = paramsE[0]
C_E = paramsE[1]

beta = paramsV[0]
C_V = paramsV[1]

# %%
# No changes need to be made to this cell, run it once the cell above is working to output your plots.

# We will now take our previous plots with data points and superimpose lines with out fit parameters to
# see how closely our data matches the hypothesis.
# Since our functions take r and not 1/r or ln(r), lets define a new linspace to use
r_array = np.linspace(4.5,9.5,100)

#Code to plot Electric Field and Voltage, just as before
plt.figure(1,figsize = [16,6])

plt.subplot(121)
plt.plot(1./radius,e_field,'go')

#Now we include our optimized curve with our data points
    # 
plt.plot(1./r_array,EField(r_array,alpha,C_E),'k-')
plt.title(e_field_plot_title)
plt.xlabel(e_field_plot_xaxis)
plt.ylabel(e_field_plot_yaxis)

plt.subplot(122)
plt.plot(radius,voltage,'bo')
plt.plot(r_array,Potential(r_array,beta,C_V),'k-')
plt.title(voltage_plot_title)
plt.xlabel(voltage_plot_xaxis)
plt.ylabel(voltage_plot_yaxis)

plt.show()

# %% [markdown]
# <strong><font color=Blue> Problem 1.19: Are our hypotheses of $|\vec{E}|\propto 1/r$ and $V \propto \ln (r)$ correct?</font></strong>

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# <strong><font color=Blue> Problem 1.20: Gauss's Law in three dimensions tells us that a point charge creates an electric field inversely proportional to the surface area of a sphere $A = 4\pi r^2$, hence $|\vec{E}|\propto 1/r^2$. What kind of electrostatic situation would give rise to an electric field field $|\vec{E}|\propto 1/r$? _Hint: The $r^2$ comes diretly from the $r^2$ dependence of the sphere in three dimensions._</font></strong>

# %% [markdown]
# _Write your answer here._
